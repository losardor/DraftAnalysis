# %%
import draftAnal20 as DA

# %%
Data = DA.initialize('./Data/INPUT/')
Data
# Out:
#           Name  ID Drafts workshopID                       Path
# 0      Pinotti   0     []          1     ./Data/WORKING/PINOTTI
# 1      Poletto   1     []          1     ./Data/WORKING/POLETTO
# 2      Valdano   2     []          1     ./Data/WORKING/VALDANO
# 3      Gravino   3     []          1     ./Data/WORKING/GRAVINO
# 4      Bokanyi   4     []          2     ./Data/WORKING/BOKANYI
# 5     Vantrijp   5     []          1    ./Data/WORKING/VANTRIJP
# 6       Londei   6     []          1      ./Data/WORKING/LONDEI
# 7   Bentkowski   7     []          1  ./Data/WORKING/BENTKOWSKI
# 8     Colliaux   8     []          1    ./Data/WORKING/COLLIAUX
# 9         Tani   9     []          1        ./Data/WORKING/TANI
# 10       Petri  10     []          1       ./Data/WORKING/PETRI
# 11      Ubaldi  11     []          1      ./Data/WORKING/UBALDI
# 12        Roux  12     []          1        ./Data/WORKING/ROUX
# 13        Ahne  13     []          2        ./Data/WORKING/AHNE
# ...

# %%
DA.fill_drafts(Data, verbose=False)
# Out:
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_11
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_50
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_17
# Copy_of_SEW1_PINOTTI_1_-_30_January__11_00
# Copy_of_SEW1_PINOTTI_1_-_30_January__10_32
# Copy_of_SEW1_PINOTTI_3_-_31_January__11_54
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_54
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_12
# Copy_of_SEW1_PINOTTI_3_-_31_January__10_41
# Copy_of_SEW1_PINOTTI_1_-_30_January__10_15
# Copy_of_SEW1_PINOTTI_1_-_30_January__10_51
# Copy_of_SEW1_PINOTTI_1_-_30_January__10_17
# Copy_of_SEW1_PINOTTI_3_-_31_January__12_04
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_31
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_34
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_39
# Copy_of_SEW1_PINOTTI_2_-_30_January__17_48
# Copy_of_SEW1_PINOTTI_4_-_31_January__15_31
# Copy_of_SEW1_PINOTTI_3_-_31_January__12_00
# Copy_of_SEW1_PINOTTI_3_-_31_January__10_37
# Copy_of_SEW1_PINOTTI_1_-_30_January__10_44
# Copy_of_SEW1_PINOTTI_1_-_30_January__10_21
# ...

# %%
Data['Path'][0]
# Out:
# './Data/WORKING/PINOTTI'

# %%
Data['Path'][0]+"/START/"
# Out:
# './Data/WORKING/PINOTTI/START/'
